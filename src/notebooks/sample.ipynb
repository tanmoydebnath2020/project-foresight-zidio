# %% [markdown]
# # Basic Python File

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../data/online_retail_II.xlsx')
df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525462.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126775
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
#Missing Values
df.isna().sum()
# Out:
# Invoice             1
# StockCode           1
# Description      2929
# Quantity            1
# InvoiceDate         1
# Price               0
# Customer ID    107928
# Country             1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Invoice             1
# StockCode           1
# Description      2929
# Quantity            1
# InvoiceDate         1
# Price               0
# Customer ID    107928
# Country             1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525462 entries, 0 to 525461
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  float64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525462 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 32.1+ MB

# %%
(df.select_dtypes(include='number') < 0).sum()
# Out:
# Quantity       12326
# Price              3
# Customer ID        0
# dtype: int64
